# %% [markdown]
# related and unrelated condition

# %%
a = 13
if a > 12:
    print("example 1")
if a > 9:
    print("example 2")
if a > 11:
    print("example 3")
# Out:
# example 1
# example 2
# example 3

# %%
# nested condition
a  = 12
if a > 9:
    if a < 15:
        print("a falls in range of 10 to 14")
# Out:
# a falls in range of 10 to 14

# %% [markdown]
# logical expression with condition (better than nesting)

# %%
if a > 9 and a < 15:
    print("a falls in range of 10 to 14")
# Out:
# a falls in range of 10 to 14

# %%
score = int(input("Enter your score: "))
if score >= 90:
    letter = "A"
elif score >= 80:
    letter = "B"
elif score >= 70:
    letter = "C"
elif score >= 60:
    letter = "D"
else:
    letter = "E"
print(letter)
# Out:
# B

# %%
name= input("Enter your name: ")
if len(name) <= 3:
    print("Name must be at least 3 characters long")
else:
    print("Good to go")
# Out:
# Name must be at least 3 characters long

# %% [markdown]
# 1. open cmd or anaconda prompt
# 2. enter command
# ```
# pip
# ```
# 3. if that works, try installing a library (internet required)
# ```
# pip install pillow
# ```
# 4. the end

# %%
from PIL import Image

# %%
Image.open(r"D:\Users\HP 346 G3\OneDrive\Pictures\ex.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080 at 0x1AFB749FFA0>
